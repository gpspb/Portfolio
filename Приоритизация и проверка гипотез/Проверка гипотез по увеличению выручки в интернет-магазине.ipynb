# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Проект:-Приоритизация-гипотез-и-проведение-A/B-тестирования." data-toc-modified-id="Проект:-Приоритизация-гипотез-и-проведение-A/B-тестирования.-1">Проект: Приоритизация гипотез и проведение A/B-тестирования.</a></span><ul class="toc-item"><li><span><a href="#1.-Цели-проекта:" data-toc-modified-id="1.-Цели-проекта:-1.1">1. Цели проекта:</a></span></li><li><span><a href="#2.-Задачи-проекта:" data-toc-modified-id="2.-Задачи-проекта:-1.2">2. Задачи проекта:</a></span></li><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-1.3">Описание данных:</a></span></li><li><span><a href="#3.-Загрузка-и-предобработка-данных:" data-toc-modified-id="3.-Загрузка-и-предобработка-данных:-1.4">3. Загрузка и предобработка данных:</a></span><ul class="toc-item"><li><span><a href="#Приоритизация-гипотез." data-toc-modified-id="Приоритизация-гипотез.-1.4.1">Приоритизация гипотез.</a></span></li></ul></li><li><span><a href="#4.-Первичная-обработка-результатов-A/B-теста." data-toc-modified-id="4.-Первичная-обработка-результатов-A/B-теста.-1.5">4. Первичная обработка результатов A/B-теста.</a></span></li><li><span><a href="#5.-Анализ-A/B-теста." data-toc-modified-id="5.-Анализ-A/B-теста.-1.6">5. Анализ A/B-теста.</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#5.1-Построим-графики-кумулятивной-выручки-по-дням-и-группам-A/B-тестирования:" data-toc-modified-id="5.1-Построим-графики-кумулятивной-выручки-по-дням-и-группам-A/B-тестирования:-1.6.0.1">5.1 Построим графики кумулятивной выручки по дням и группам A/B-тестирования:</a></span></li><li><span><a href="#5.2-Построим-графики-кумулятивного-среднего-чека-по-группам-A/B-тестирования:" data-toc-modified-id="5.2-Построим-графики-кумулятивного-среднего-чека-по-группам-A/B-тестирования:-1.6.0.2">5.2 Построим графики кумулятивного среднего чека по группам A/B-тестирования:</a></span></li><li><span><a href="#5.3-Построим-графики-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A:" data-toc-modified-id="5.3-Построим-графики-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A:-1.6.0.3">5.3 Построим графики относительного изменения кумулятивного среднего чека группы B к группе A:</a></span></li><li><span><a href="#5.4-Построим-графики-среднего-количества-заказов-на-посетителя-групп-A-и-B:" data-toc-modified-id="5.4-Построим-графики-среднего-количества-заказов-на-посетителя-групп-A-и-B:-1.6.0.4">5.4 Построим графики среднего количества заказов на посетителя групп A и B:</a></span></li><li><span><a href="#5.5-Построим-графики-относительного-изменения-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A:" data-toc-modified-id="5.5-Построим-графики-относительного-изменения-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A:-1.6.0.5">5.5 Построим графики относительного изменения среднего количества заказов на посетителя группы B к группе A:</a></span></li><li><span><a href="#5.6-Построим-точечную-диаграмму-числа-заказов-на-одного-пользователя:" data-toc-modified-id="5.6-Построим-точечную-диаграмму-числа-заказов-на-одного-пользователя:-1.6.0.6">5.6 Построим точечную диаграмму числа заказов на одного пользователя:</a></span></li><li><span><a href="#5.7-Посчитаем-выборочные-перцентили-количества-заказов-на-одного-пользователя:" data-toc-modified-id="5.7-Посчитаем-выборочные-перцентили-количества-заказов-на-одного-пользователя:-1.6.0.7">5.7 Посчитаем выборочные перцентили количества заказов на одного пользователя:</a></span></li><li><span><a href="#5.8-Построим-точечный-график-стоимостей-заказов." data-toc-modified-id="5.8-Построим-точечный-график-стоимостей-заказов.-1.6.0.8">5.8 Построим точечный график стоимостей заказов.</a></span></li><li><span><a href="#5.9-Посчитаем-выборочные-перцентили-стоимости-заказов:" data-toc-modified-id="5.9-Посчитаем-выборочные-перцентили-стоимости-заказов:-1.6.0.9">5.9 Посчитаем выборочные перцентили стоимости заказов:</a></span></li></ul></li></ul></li><li><span><a href="#6.-Проверка-статистически-значимых-результатов." data-toc-modified-id="6.-Проверка-статистически-значимых-результатов.-1.7">6. Проверка статистически значимых результатов.</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#6.1-Расчёт-статистической-значимости-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-(до-удаления-выбросов):" data-toc-modified-id="6.1-Расчёт-статистической-значимости-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-(до-удаления-выбросов):-1.7.0.1">6.1 Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами (до удаления выбросов):</a></span></li><li><span><a href="#6.2-Расчёт-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-(до-удаления-выбросов):" data-toc-modified-id="6.2-Расчёт-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-(до-удаления-выбросов):-1.7.0.2">6.2 Расчёт статистической значимости различий в среднем чеке заказа между группами (до удаления выбросов):</a></span></li><li><span><a href="#6.3-Расчёт-статистической-значимости-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-(после-удаления-выбросов):" data-toc-modified-id="6.3-Расчёт-статистической-значимости-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-(после-удаления-выбросов):-1.7.0.3">6.3 Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами (после удаления выбросов):</a></span></li><li><span><a href="#6.4-Расчёт-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-(после-удаления-выбросов):" data-toc-modified-id="6.4-Расчёт-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-(после-удаления-выбросов):-1.7.0.4">6.4 Расчёт статистической значимости различий в среднем чеке заказа между группами (после удаления выбросов):</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Итог-проекта:" data-toc-modified-id="Итог-проекта:-2">Итог проекта:</a></span><ul class="toc-item"><li><span><a href="#Рекомендации:" data-toc-modified-id="Рекомендации:-2.1">Рекомендации:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Проект: Приоритизация гипотез и проведение A/B-тестирования.

# %% [markdown]
# **В данном проекте нам предстоит работать с данными одного крупного интернет-магазина. Вместе с отделом маркетинга было сформулировано некоторое количество гипотез по увеличению выручки компании. Нам предстоит приоритизировать их, провести A/B-тестирование и правильно интерпритировать полученные результаты.**

# %% [markdown]
# ## 1. Цели проекта:
# - Приоритиризировать гипотезы для эффективного использования ресурсов компании.
# - Построить графики изменения выручки по группам и проанализировать полученные результаты.
# - Исследовать изменения среднего чека по группам и проанализировать полученные результаты.
# - Проанализировать показатели количества заказов на пользователя и на каждую группу.
# - Рассчитать показатели стоимости заказов для каждой из групп.
# - Сформировать единую картину эффективности применения гипотез и предоставить рекомендации по дальнейшему развитию компании или продолжению теста.

# %% [markdown]
# ## 2. Задачи проекта:
# - Загрузить и изучить данные по выдвинутым гипотезам.
# - Приоритизировать гипотезы на основе фреймворков `ICE` и `RICE`.
# - Загрузить и изучить данные по полученным результатам A/B-тестов.
# - Построить и проанализировать графики кумулятивной выручки по группам.
# - Построить и проанализировать графики кумулятивного среднего чека по группам.
# - Построить и проанализировать графики кумулятивного среднего количества заказов на посетителя.
# - Подготовить и проанализировать точечный график количества заказов по пользователям.
# - Рассчитать перцентили для количества заказов на пользователя.
# - Подготовить и проанализировать точечный график количества заказов по пользователям.
# - Рассчитать перцентили для стоимости заказов.
# - Выявить границу аномальных значений.
# - Подготовить и проанализировать точечный график стоимостей заказов.
# - Просчитать статистическую значимость для показателей с "сырых" данных.
# - Просчитать статистическую значимость для показателей с "очищенных" данных.
# - Принять решение по результатам A/B-теста и сформулировать вывод.

# %% [markdown]
# ## Описание данных:

# %% [markdown]
# -----
# Файл **hypothesis.csv**:
# - Hypothesis — краткое описание гипотезы;
# - Reach — охват пользователей по 10-балльной шкале;
# - Impact — влияние на пользователей по 10-балльной шкале;
# - Confidence — уверенность в гипотезе по 10-балльной шкале;
# - Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
# -----
# Файл **orders.csv**:
# - transactionId — идентификатор заказа;
# - visitorId — идентификатор пользователя, совершившего заказ;
# - date — дата, когда был совершён заказ;
# - revenue — выручка заказа;
# - group — группа A/B-теста, в которую попал заказ.
# -----
# Файл **visitors.csv**:
# - date — дата;
# - group — группа A/B-теста;
# - visitors — количество пользователей в указанную дату в указанной группе A/B-теста
# -----

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Проект:-Приоритизация-гипотез-и-проведение-A/B-тестирования." data-toc-modified-id="Проект:-Приоритизация-гипотез-и-проведение-A/B-тестирования.-1">Проект: Приоритизация гипотез и проведение A/B-тестирования.</a></span><ul class="toc-item"><li><span><a href="#1.-Цели-проекта:" data-toc-modified-id="1.-Цели-проекта:-1.1">1. Цели проекта:</a></span></li><li><span><a href="#2.-Задачи-проекта:" data-toc-modified-id="2.-Задачи-проекта:-1.2">2. Задачи проекта:</a></span></li><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-1.3">Описание данных:</a></span></li><li><span><a href="#3.-Загрузка-и-предобработка-данных:" data-toc-modified-id="3.-Загрузка-и-предобработка-данных:-1.4">3. Загрузка и предобработка данных:</a></span><ul class="toc-item"><li><span><a href="#Приоритизация-гипотез." data-toc-modified-id="Приоритизация-гипотез.-1.4.1">Приоритизация гипотез.</a></span></li></ul></li><li><span><a href="#4.-Первичная-обработка-результатов-A/B-теста." data-toc-modified-id="4.-Первичная-обработка-результатов-A/B-теста.-1.5">4. Первичная обработка результатов A/B-теста.</a></span></li><li><span><a href="#5.-Анализ-A/B-теста." data-toc-modified-id="5.-Анализ-A/B-теста.-1.6">5. Анализ A/B-теста.</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#5.1-Построим-графики-кумулятивной-выручки-по-дням-и-группам-A/B-тестирования:" data-toc-modified-id="5.1-Построим-графики-кумулятивной-выручки-по-дням-и-группам-A/B-тестирования:-1.6.0.1">5.1 Построим графики кумулятивной выручки по дням и группам A/B-тестирования:</a></span></li><li><span><a href="#5.2-Построим-графики-кумулятивного-среднего-чека-по-группам-A/B-тестирования:" data-toc-modified-id="5.2-Построим-графики-кумулятивного-среднего-чека-по-группам-A/B-тестирования:-1.6.0.2">5.2 Построим графики кумулятивного среднего чека по группам A/B-тестирования:</a></span></li><li><span><a href="#5.3-Построим-графики-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A:" data-toc-modified-id="5.3-Построим-графики-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A:-1.6.0.3">5.3 Построим графики относительного изменения кумулятивного среднего чека группы B к группе A:</a></span></li><li><span><a href="#5.4-Построим-графики-среднего-количества-заказов-на-посетителя-групп-A-и-B:" data-toc-modified-id="5.4-Построим-графики-среднего-количества-заказов-на-посетителя-групп-A-и-B:-1.6.0.4">5.4 Построим графики среднего количества заказов на посетителя групп A и B:</a></span></li><li><span><a href="#5.5-Построим-графики-относительного-изменения-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A:" data-toc-modified-id="5.5-Построим-графики-относительного-изменения-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A:-1.6.0.5">5.5 Построим графики относительного изменения среднего количества заказов на посетителя группы B к группе A:</a></span></li><li><span><a href="#5.6-Построим-точечную-диаграмму-числа-заказов-на-одного-пользователя:" data-toc-modified-id="5.6-Построим-точечную-диаграмму-числа-заказов-на-одного-пользователя:-1.6.0.6">5.6 Построим точечную диаграмму числа заказов на одного пользователя:</a></span></li><li><span><a href="#5.7-Посчитаем-выборочные-перцентили-количества-заказов-на-одного-пользователя:" data-toc-modified-id="5.7-Посчитаем-выборочные-перцентили-количества-заказов-на-одного-пользователя:-1.6.0.7">5.7 Посчитаем выборочные перцентили количества заказов на одного пользователя:</a></span></li><li><span><a href="#5.8-Построим-точечный-график-стоимостей-заказов." data-toc-modified-id="5.8-Построим-точечный-график-стоимостей-заказов.-1.6.0.8">5.8 Построим точечный график стоимостей заказов.</a></span></li><li><span><a href="#5.9-Посчитаем-выборочные-перцентили-стоимости-заказов:" data-toc-modified-id="5.9-Посчитаем-выборочные-перцентили-стоимости-заказов:-1.6.0.9">5.9 Посчитаем выборочные перцентили стоимости заказов:</a></span></li></ul></li></ul></li><li><span><a href="#6.-Проверка-статистически-значимых-результатов." data-toc-modified-id="6.-Проверка-статистически-значимых-результатов.-1.7">6. Проверка статистически значимых результатов.</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#6.1-Расчёт-статистической-значимости-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-(до-удаления-выбросов):" data-toc-modified-id="6.1-Расчёт-статистической-значимости-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-(до-удаления-выбросов):-1.7.0.1">6.1 Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами (до удаления выбросов):</a></span></li><li><span><a href="#6.2-Расчёт-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-(до-удаления-выбросов):" data-toc-modified-id="6.2-Расчёт-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-(до-удаления-выбросов):-1.7.0.2">6.2 Расчёт статистической значимости различий в среднем чеке заказа между группами (до удаления выбросов):</a></span></li><li><span><a href="#6.3-Расчёт-статистической-значимости-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-(после-удаления-выбросов):" data-toc-modified-id="6.3-Расчёт-статистической-значимости-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-(после-удаления-выбросов):-1.7.0.3">6.3 Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами (после удаления выбросов):</a></span></li><li><span><a href="#6.4-Расчёт-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-(после-удаления-выбросов):" data-toc-modified-id="6.4-Расчёт-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-(после-удаления-выбросов):-1.7.0.4">6.4 Расчёт статистической значимости различий в среднем чеке заказа между группами (после удаления выбросов):</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Итог-проекта:" data-toc-modified-id="Итог-проекта:-2">Итог проекта:</a></span><ul class="toc-item"><li><span><a href="#Рекомендации:" data-toc-modified-id="Рекомендации:-2.1">Рекомендации:</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## 3. Загрузка и предобработка данных:

# %% [markdown]
#  **Импортируем все необходимые библиотеки для работы и прочитаем датасеты.**

# %%
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import datetime as dt
import numpy as np
from matplotlib import pyplot as plt
from pandas import option_context
import os

pd.set_option('float_format', '{:f}'.format)

# %%
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (20, 15)

# %%
hyptF = r'C:\Users\falku\Принятие решений в бизнесе\hypothesis.csv'
hyptY = '/datasets/hypothesis.csv'
ordersF = r'C:\Users\falku\Принятие решений в бизнесе\orders.csv'
ordersY = '/datasets/orders.csv'
visF = r'C:\Users\falku\Принятие решений в бизнесе\visitors.csv'
visY = '/datasets/visitors.csv'

if os.path.exists(hyptF) and os.path.exists(ordersF) and os.path.exists(visF):
    df_h = pd.read_csv(hyptF)
    df_o = pd.read_csv(ordersF)
    df_v = pd.read_csv(visF)
elif os.path.exists(hyptY) and os.path.exists(ordersY) and os.path.exists(visY):
    df_h = pd.read_csv(hyptY)
    df_o = pd.read_csv(ordersY)
    df_v = pd.read_csv(visY)
else:
    print('Упс... что-то пошло не так')

# %% [markdown]
# ### Приоритизация гипотез.

# %% [markdown]
# Для начала изучим данные:

# %%
with option_context('display.max_colwidth', 400):
    display(df_h.head(10))
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %%
df_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes

# %% [markdown]
# Никаких ошибок с форматом данных в датафрейме нет, однако, было бы неплохо перевести все названия столбцов в нижний регистр.

# %%
df_h.columns = df_h.columns.str.lower()

# %% [markdown]
# В датасете у нас всего 9 записей с аналогичным количеством гипотез, для каждой присвоены значения охвата пользователей(reach), предполагаемого влияния(impact), степени уверенности в присвоенных значениях(confidence) и величины трудозатрат на тестирование гипотезы(efforts) по шкале от одного до десяти.

# %% [markdown]
# Приоритизируем гипотезы с помощью фреймворков `ICE` и `RICE` и добавим эти показатели в датафрейм.

# %%
df_h['ICE'] = (df_h['impact'] * df_h['confidence']) / df_h['efforts']
df_h[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False).style.format({('ICE'): "{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3d3a1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hypothesis</th>        <th class="col_heading level0 col1" >ICE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d3a1_level0_row0" class="row_heading level0 row0" >8</th>
#                         <td id="T_3d3a1_row0_col0" class="data row0 col0" >Запустить акцию, дающую скидку на товар в день рождения</td>
#                         <td id="T_3d3a1_row0_col1" class="data row0 col1" >16.20</td>
#             </tr>
#             <tr>
#                         <th id="T_3d3a1_level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_3d3a1_row1_col0" class="data row1 col0" >Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей</td>
#                         <td id="T_3d3a1_row1_col1" class="data row1 col1" >13.33</td>
# ...

# %% [markdown]
# Лидерами по `ICE` оказались гипотезы с индексами 8, 0, 7 и 6. Заметим, что при расчёте рейтинга `ICE` не учитывается охват аудитории, поэтому гипотезу под номером 8 не стоит рассматривать как самую срочную. К тому же, чтобы собрать две релевантные группы по количеству пользователей для данного теста может потребоваться очень много времени.

# %%
df_h['RICE'] = (df_h['reach'] * df_h['impact'] * df_h['confidence']) / df_h['efforts']
df_h[['hypothesis', 'RICE']].sort_values(by='RICE', ascending=False).style.format({('RICE'): "{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_554b3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hypothesis</th>        <th class="col_heading level0 col1" >RICE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_554b3_level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_554b3_row0_col0" class="data row0 col0" >Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок</td>
#                         <td id="T_554b3_row0_col1" class="data row0 col1" >112.00</td>
#             </tr>
#             <tr>
#                         <th id="T_554b3_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_554b3_row1_col0" class="data row1 col0" >Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа</td>
# ...

# %% [markdown]
# Лидерами по `RICE` оказались гипотезы с индексами 7, 2, 0 и 6. Таким образом, с учётом пересечения результатов двух фреймворков, предпочтение стоит отдать гипотезам №0:**Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей**, №7: **Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок** и №6: **Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию**.

# %% [markdown]
# ## 4. Первичная обработка результатов A/B-теста.

# %% [markdown]
# Для начала познакомимся с данными.

# %%
df_o.head(5)
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B

# %%
df_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %%
unique_counts = pd.DataFrame.from_records([(col, df_o[col].nunique()) for col in df_o.columns],
                                          columns=['column_name', 'num_unique']).sort_values(by=['num_unique'])

# %%
unique_counts
# Out:
#      column_name  num_unique
# 4          group           2
# 2           date          31
# 3        revenue         713
# 1      visitorId        1031
# 0  transactionId        1197

# %% [markdown]
# Проверим датасет на явные дубликаты по всем столбцам и на наличие пропусков.

# %%
df_o[df_o[['transactionId', 'visitorId', 'date', 'revenue', 'group']].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [transactionId, visitorId, date, revenue, group]
# Index: []

# %%
df_o.isna().sum()
# Out:
# transactionId    0
# visitorId        0
# date             0
# revenue          0
# group            0
# dtype: int64

# %% [markdown]
# Записей с полными дубликатами в датафрейме нет. Отдельных дубликатов в столбце `transactionId` также нет, так как количество уникальных значений в этом столбце соответствует количеству строк. Пропусков не обнаружено.

# %% [markdown]
# Выполним проверку, есть ли такие пользователи, которые из-за ошибки могли оказаться в обеих группах одновременно:

# %%
in_group_a = df_o[df_o['group'] == 'A']['visitorId'].isin([df_o['visitorId']]).all()
in_group_b = df_o[df_o['group'] == 'B']['visitorId'].isin([df_o['visitorId']]).all()

if in_group_a and in_group_b:
    print(f"Пользователь {df_o['visitorId'].values[0]} есть в обеих группах A и B")
else:
    print(f"Каждый пользователь в датафрейме принадлежит только одной группе")
# Out:
# Каждый пользователь в датафрейме принадлежит только одной группе

# %% [markdown]
# **Теперь проделаем аналогичные действия со вторым датафреймом.**

# %%
df_v.head(5)
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756

# %%
df_v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
unique_counts = pd.DataFrame.from_records([(col, df_v[col].nunique()) for col in df_v.columns],
                                          columns=['column_name', 'num_unique']).sort_values(by=['num_unique'])

# %%
unique_counts
# Out:
#   column_name  num_unique
# 1       group           2
# 0        date          31
# 2    visitors          58

# %% [markdown]
# Проверим датасет на явные дубликаты по всем столбцам и на наличие пропусков.

# %%
df_v[df_v[['group', 'date', 'visitors']].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [date, group, visitors]
# Index: []

# %%
df_v.isna().sum()
# Out:
# date        0
# group       0
# visitors    0
# dtype: int64

# %% [markdown]
# Явных дубликатов, как и пропусков, в датафрейме нет.

# %% [markdown]
# **Есть небольшие проблемы с названиями первых двух столбцов в датафрейме `orders`, дате необходимо присвоить соответствующий формат `datetime`. Помимо этого, в датасете `orders` столбцам с `id`(транзакций и пользователей) присвоен целочисленный тип данных, хотя тут лучше подойдёт тип `object`.**

# %%
df_o.rename(columns = {'transactionId':'transaction_id', 'visitorId':'visitor_id'}, inplace = True) #Переименование
df_o['transaction_id'] = df_o['transaction_id'].astype('object') #Изменение типа данных на object
df_o['visitor_id'] = df_o['visitor_id'].astype('object') #Изменение типа данных на object
df_o['date'] = pd.to_datetime(df_o['date']) #Перевод поля с датой в datetime
df_v['date'] = pd.to_datetime(df_v['date']) #Перевод поля с датой в datetime

# %% [markdown]
# Теперь мы можем приступить к анализу.

# %% [markdown]
# ## 5. Анализ A/B-теста.

# %% [markdown]
# Начнём с подготовки данных. Чтобы построить графики, нужно собрать кумулятивные данные. Найдём число уникальных ID заказов и пользователей. Подсчитаем сумму средних чеков.

# %%
datesGroups = df_o[['date','group']].drop_duplicates()
ordersAggregated = datesGroups.apply(lambda x: df_o[np.logical_and(df_o['date'] <= x['date'], df_o['group'] == x['group'])]\
.agg({'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %% [markdown]
# Получим агрегированные кумулятивные по дням данные о посетителях интернет-магазина:

# %%
visitorsAggregated = datesGroups.apply(lambda x: df_v[np.logical_and(df_v['date'] <= x['date'], df_v['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %% [markdown]
# Объединим обе таблицы в одну

# %%
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

print(cumulativeData.head(5))
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      24      20   148579       719
# 1 2019-08-01     B      21      20   101217       713
# 2 2019-08-02     A      44      38   242401      1338
# 3 2019-08-02     B      45      43   266748      1294
# 4 2019-08-03     A      68      62   354874      1845

# %% [markdown]
# Небольшой фактчекинг, проверим минимальные и максимальные даты в первоначальных данных и в кумулятивных.

# %%
df_o[['date']].agg({'date':['min', 'max']})
# Out:
#           date
# min 2019-08-01
# max 2019-08-31

# %%
cumulativeData[['date']].agg({'date':['min', 'max']})
# Out:
#           date
# min 2019-08-01
# max 2019-08-31

# %% [markdown]
# Отлично, ошибок не выявлено.

# %% [markdown]
# #### 5.1 Построим графики кумулятивной выручки по дням и группам A/B-тестирования:

# %%
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

plt.legend()
plt.title('Кумулятивная выручка по дням')
plt.grid(True)
plt.xlabel('Дата')
plt.ylabel('Выручка')
plt.show()

# %% [markdown]
# На графике мы можем наблюдать резкий скачок выручки 19-го августа для группы `B`, это может сигнализировать о всплесках числа заказов, либо о появлении очень дорогих заказов в выборке. График группы `A` выглядит довольно стабильным. Необходимо получить дополнительную информацию.

# %% [markdown]
# #### 5.2 Построим графики кумулятивного среднего чека по группам A/B-тестирования:

# %% [markdown]
# Для этого разделим кумулятивную выручку на кумулятивное число заказов:

# %%
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')

plt.title('Кумулятивный средний чек')
plt.grid(True)
plt.xlabel('Дата')
plt.ylabel('Размер среднего чека')
plt.legend()
plt.show()

# %% [markdown]
# На графике наблюдаем похожую ситуацию. Резкий рост в группе `B` 19-го августа. Также заметно, как после резкого скачка наблюдается нисходящий тренд. Подобные экстремумы и дальнейшая динамика указывают на аномальную природу происхождения значений за 19-е число. График группы `A` выглядит стабильным.

# %% [markdown]
# #### 5.3 Построим графики относительного изменения кумулятивного среднего чека группы B к группе A:

# %% [markdown]
# Для этого соберём данные в одном датафрейме, высчитаем отношение средних чеков и добавим на график горизонтальную ось.

# %%
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])


plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Относительное изменение кумулятивного среднего чека')
plt.grid(True)
plt.xlabel('Дата')
plt.ylabel('Разница')
plt.show()

# %% [markdown]
# Линия кидается из стороны в сторону, где-то в данных явно есть выборосы. Поскольку некоторые гипотезы(2 и 6) предполагают увеличение среднего количества заказов на посетителя, рассмотрим и эти значения на графике.

# %% [markdown]
# #### 5.4 Построим графики среднего количества заказов на посетителя групп A и B:

# %%
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

cumulativeDataA = cumulativeData[cumulativeData['group']=='A']
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']


plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.legend()
plt.title('Среднее количество заказов на посетителя')
plt.grid(True)
plt.xlabel('Дата')
plt.ylabel('Количество заказов')
plt.show()

# %% [markdown]
# #### 5.5 Построим графики относительного изменения среднего количества заказов на посетителя группы B к группе A:

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост среднего количества заказов на посетителя группы B относительно группы A")
plt.legend()

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.15, color='grey', linestyle='--')
plt.grid(True)
plt.xlabel('Дата')
plt.ylabel('Разница')
plt.show()

# %% [markdown]
# Хотя графики и очень скачкообразные, уже сейчас заметно, что среднее количество заказов на посетителя из группы `A` выстраивается вокруг значения `0.03`, а у пользователей из группы `B` вокруг значения `0.034`, что больше на целых `13%`. Впрочем, сперва стоит проанализировать аномалии, возможно, они изменят картину.

# %% [markdown]
# #### 5.6 Построим точечную диаграмму числа заказов на одного пользователя:

# %% [markdown]
# Подсчитаем количество заказов по пользователям

# %%
ordersByUsers = (
    df_o.groupby('visitor_id', as_index=False)
    .agg({'transaction_id': 'nunique'})
)

ordersByUsers.columns = ['visitor_id', 'orders']

# %% [markdown]
# Построим точечную диаграмму.

# %%
x_values = pd.Series(range(0,len(ordersByUsers)))

plt.scatter(x_values, ordersByUsers['orders'], alpha=0.5)
plt.title('Точечная диаграмма количества заказов на одного пользователя')
plt.grid(True)
plt.xlabel('Номер пользователя')
plt.ylabel('Количество заказов')
plt.show()

# %% [markdown]
# Из диаграммы рассеивания можем сделать вывод, что подавляющее большинство пользователей совершают до 4-х заказов, но подобной точности недостаточно, нужно рассчитать перцентили.

# %% [markdown]
# #### 5.7 Посчитаем выборочные перцентили количества заказов на одного пользователя:

# %% [markdown]
# Рассчитаем 95, 96, 97, 98 и 99 перцентили

# %%
np.percentile(ordersByUsers['orders'], [95, 96, 97, 98, 99])
# Out:
# array([2., 2., 2., 3., 4.])

# %% [markdown]
# * Из данных следует, что не более 2% от всех пользователей совершили 3 заказа и более. Обозначим это значение за границу выбросов. Но выбросы могут скрываться не только в аномальном количестве заказов, но также и в среднем чеке каждого заказа по отдельности.

# %% [markdown]
# #### 5.8 Построим точечный график стоимостей заказов.

# %%
x_values = pd.Series(range(0,len(df_o['revenue'])))

plt.scatter(x_values, df_o['revenue'], alpha=0.5)
plt.title('Точечная диаграмма стоимости заказов')
plt.grid(True)
plt.xlabel('Номер заказа')
plt.ylabel('Стоимость')
plt.show()

# %% [markdown]
# Всю диаграмму вытягивает вверх заказ на 1,25 млн., немного ограничим показатель стоимости для большей наглядности графика.

# %%
limited_orders = df_o[df_o['revenue']<=200000]['revenue']
lx_values = pd.Series(range(0,len(limited_orders)))

plt.scatter(lx_values, limited_orders, alpha=0.5)
plt.title('Точечная диаграмма стоимости заказов')
plt.grid(True)
plt.xlabel('Номер заказа')
plt.ylabel('Стоимость')
plt.show()

# %% [markdown]
# Так намного лучше. Из графика можем наблюдать, что подавляющее большинство заказов укладывается в сумму до 40 000, обратимся к перцентилям.

# %% [markdown]
# #### 5.9 Посчитаем выборочные перцентили стоимости заказов:

# %%
np.percentile(df_o['revenue'], [95, 96, 97, 98, 99])
# Out:
# array([28000. , 31382. , 35485. , 44133.2, 58233.2])

# %% [markdown]
# * Из данных следует, что не более 3% заказов обходятся дороже 44133.2 у.е., обозначим это значение за границу аномалий.

# %% [markdown]
# ## 6. Проверка статистически значимых результатов.

# %% [markdown]
# #### 6.1 Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами (до удаления выбросов):

# %% [markdown]
# ***
#
# - **H0**: Нулевая гипотеза предполагает, что две совокупности (A и B) не имеют статистически значимых различий по показателю среднего количества заказов на пользователя.
# - **H1**: Альтернативная гипотеза предполагает, что две совокупности (A и B) имеют статистически значимые различия по показателю среднего количества заказов на пользователя.
# - **α** (уровень значимости статистического теста) = 0.05
# - Для расчёта статистической значимости результатов теста будет применён **U-критерий Манна - Уитни**. Распределение не является нормальным.
#
# ***

# %% [markdown]
# Рассчитаем кумулятивное количество пользователей в выбранную дату в группе A и Б.

# %%
visitorsADaily = df_v[df_v['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']
visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = df_v[df_v['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

# %% [markdown]
# Далее подсчитаем суммарное количество заказов до выбранной даты включительно в группе А и B

# %%
ordersADaily = (
    df_o[df_o['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    df_o[df_o['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

# %% [markdown]
# Объединим столбцы с помощью `merge`.

# %%
data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

# %% [markdown]
# Создадим переменные `ordersByUsersA` и `ordersByUsersB` с каждым покупателем и его количеством заказов.

# %%
ordersByUsersA = (
    df_o[df_o['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersA.columns = ['visitor_id', 'orders']

ordersByUsersB = (
    df_o[df_o['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersB.columns = ['visitor_id', 'orders']

# %% [markdown]
# Объявим переменные `sampleA` и `sampleB`, где присвоим пользователям без заказов нули в столбце `orders`.

# %%
sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %%
p_value = '{0:.3f}'.format(stats.mannwhitneyu(sampleA, sampleB)[1])
p_value
# Out:
# '0.017'

# %% [markdown]
# `p_value` значительно меньше `0.05`, а значит, перед нами статистический значимый результат теста и у нас есть основания отклонить нулевую гипотезу. Однако не стоит забывать, что мы пока не трогали выбросы. Теперь высчитаем относительную разницу.

# %%
print("{0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# 0.138

# %% [markdown]
# Как и было замечено ранее по графикам, разница составила порядка 13-14%. Перейдём к расчёту среднего чека.

# %% [markdown]
# #### 6.2 Расчёт статистической значимости различий в среднем чеке заказа между группами (до удаления выбросов):

# %% [markdown]
# ***
#
# - **H0**: Нулевая гипотеза предполагает, что две совокупности (A и B) не имеют статистически значимых различий по показателю среднего чека покупки.
# - **H1**: Альтернативная гипотеза предполагает, что две совокупности (A и B) имеют статистически значимые различия по показателю среднего среднего чека покупки.
# - **α** (уровень значимости статистического теста) = 0.05
# - Для расчёта статистической значимости результатов теста будет применён **U-критерий Манна - Уитни**. Распределение не является нормальным.
#
# ***

# %% [markdown]
# Чтобы рассчитать статистическую значимость различий в среднем чеке, передадим критерию `mannwhitneyu()` данные о выручке с заказов.

# %%
p_value = '{0:.3f}'.format(stats.mannwhitneyu(df_o[df_o['group']=='A']['revenue'], df_o[df_o['group']=='B']['revenue'])[1])
p_value
# Out:
# '0.729'

# %% [markdown]
# `p_value` значительно больше порога в `0.05`, получить статистически значимый результат на "сырых" данных не вышло. Оснований для отклонения нулевой гипотезы нет. Выясним относительную разницу.

# %%
print('{0:.3f}'.format(df_o[df_o['group']=='B']['revenue'].mean()/df_o[df_o['group']=='A']['revenue'].mean()-1))
# Out:
# 0.259

# %% [markdown]
# Относительная разница составляет порядка 26%, но при этом статистически значимый результат не получен, что явно намекает нам на "аномальную" природу возникновения таких различий. Вероятнее всего, именно в группе `B` находился тот самый одиночный заказ на 1,25 млн у.е.

# %% [markdown]
# Пора приступить к очистке данных от выбросов и проверить, какие расчёты мы получим по ним.

# %% [markdown]
# Узнаем, сколько всего аномальных пользователей:

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > np.percentile(ordersByUsers['orders'], 97)]['visitor_id'],
        ordersByUsersB[ordersByUsersB['orders'] > np.percentile(ordersByUsers['orders'], 97)]['visitor_id'],
    ],
    axis=0,
)
usersWithExpensiveOrders = df_o[df_o['revenue'] > np.percentile(df_o['revenue'], 98)]['visitor_id']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print(abnormalUsers.head(5))
print(abnormalUsers.shape[0])
# Out:
# 1099    148427295
# 18      199603092
# 23      237748145
# 37      249864742
# 68      457167155
# Name: visitor_id, dtype: object
# 40

# %% [markdown]
# Всего 40 аномальных пользователей. Уберём их из данных и посмотрим, как они повлияли на результаты:

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# #### 6.3 Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами (после удаления выбросов):

# %% [markdown]
# ***
#
# - **H0**: Нулевая гипотеза предполагает, что две совокупности (A и B) не имеют статистически значимых различий по показателю среднего количества заказов на пользователя.
# - **H1**: Альтернативная гипотеза предполагает, что две совокупности (A и B) имеют статистически значимые различия по показателю среднего количества заказов на пользователя.
# - **α** (уровень значимости статистического теста) = 0.05
# - Для расчёта статистической значимости результатов теста будет применён **U-критерий Манна - Уитни**. Распределение не является нормальным.
#
# ***

# %% [markdown]
# Применим статистический критерий Манна-Уитни к обработанным данным.

# %%
p_value = '{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1])
p_value
# Out:
# '0.007'

# %% [markdown]
# Результаты стали ещё более статистически значимыми после удаления выбросов, есть все основания отвергать нулевую гипотезу. Посмотрим, как обстоят дела с относительной разницей в среднем количестве заказов на посетителя между группами.

# %%
print('{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# 0.185

# %% [markdown]
# Результаты улучшились. Таким образом, мы получили статистически значимый результат в группе `B`, позволяющий увеличить среднее количество заказов для одного посетителя на `18,5%`.

# %% [markdown]
# #### 6.4 Расчёт статистической значимости различий в среднем чеке заказа между группами (после удаления выбросов):

# %% [markdown]
# ***
#
# - **H0**: Нулевая гипотеза предполагает, что две совокупности (A и B) не имеют статистически значимых различий по показателю среднего чека покупки.
# - **H1**: Альтернативная гипотеза предполагает, что две совокупности (A и B) имеют статистически значимые различия по показателю среднего среднего чека покупки.
# - **α** (уровень значимости статистического теста) = 0.05
# - Для расчёта статистической значимости результатов теста будет применён **U-критерий Манна - Уитни**. Распределение не является нормальным.
#
# ***

# %%
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            df_o[
                np.logical_and(
                    df_o['group'] == 'A',
                    np.logical_not(df_o['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
            df_o[
                np.logical_and(
                    df_o['group'] == 'B',
                    np.logical_not(df_o['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "{0:.3f}".format(
        df_o[
            np.logical_and(
                df_o['group'] == 'B',
                np.logical_not(df_o['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / df_o[
            np.logical_and(
                df_o['group'] == 'A',
                np.logical_not(df_o['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# 0.994
# 0.037

# %% [markdown]
# После обработки данных от выбросов, `p_value` значительно выросло, подобравшись в плотную к отметке в единицу, что означает почти 100% вероятность получить подобную разницу случайным образом. Как и предполагалось, после удаления выбросов, относительная разница между средними чеками в группах опустилась до `3,7%`. Оснований отвергать нулевую гипотезу нет.

# %% [markdown]
#  # Итог проекта:

# %% [markdown]
# - При помощи фрейморков `ICE` и `RICE` были выявлены первоочередные гипотезы для последующих A/B-тестов: Гипотезы № 0, 7 и 6.
# - Результатом A/B тестирования стало получение статистически значимого результата в разнице среднего количества заказов на одного пользователя между группами. Удалось увеличить этот показатель на `18,5%`. Нулевая гипотеза отвергнута.
# - Статистически значимого результата в разнице среднего чека у пользователей из разных групп получено не было. Нулевая гипотеза верна.

# %% [markdown]
#  ## Рекомендации:

# %% [markdown]
# - Остановить A/B-тест, зафиксировать победу группы `B`.
