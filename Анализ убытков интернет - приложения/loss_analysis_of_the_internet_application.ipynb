# %% [markdown]
# # Проект: Оценка эффективности проведения рекламной компании приложения Procrastinate Pro+.

# %% [markdown]
# **В данном проекте мы будем работать с данными развлекательного приложения Procrastinate Pro+, а именно: логами посещений, логами покупок пользователей и рекламными расходами на их привлечение. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.**

# %% [markdown]
# ## 1. Цели проекта:
# - С помощью пользовательских метрик, определить качество пользователей.
# - Выявить и сформировать подробные профили пользователей(устройство, регион).
# - Оценить стоимость привлечения пользователей в приложение из разных каналов.
# - Сформировать вывод о рентабельности различных каналов привлечения клиентов.
# - Выявить причины неэффективного маркетингового подхода.
# - На основе данных, предоставить рекомендации по дальшнейшей работе для маркетингового отдела.

# %% [markdown]
# ## 2. Задачи проекта:
# - Загрузить и изучить данные по визитам, заказам и рекламным расходам приложения.
# - Составить профили пользователей.
# - Выяснить, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.
# - Узнать, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.
# - Изучить рекламные источники привлечения и определить каналы, из которых пришло больше всего платящих пользователей.
# - Посчитать общую сумму расходов на маркетинг.
# - Выяснить, как траты распределены по рекламным источникам.
# - Построить визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику.
# - Узнать, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.
# - Проанализировать окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.
# - Исследовать конверсию пользователей и динамику её изменения. То же самое сделать с удержанием пользователей.
# - Выделить причины неэффективности привлечения пользователей.
# - Сформулировать рекомендации для отдела маркетинга.

# %% [markdown]
# ## Описание данных:

# %% [markdown]
# -----
# Файл **visits_info_short.csv**:
# - User Id — уникальный идентификатор пользователя,
# - Region — страна пользователя,
# - Device — тип устройства пользователя,
# - Channel — идентификатор источника перехода,
# - Session Start — дата и время начала сессии,
# - Session End — дата и время окончания сессии.
# -----
# Файл **orders_info_short.csv**:
# - User Id — уникальный идентификатор пользователя,
# - Event Dt — дата и время покупки,
# - Revenue — сумма заказа.
# -----
# Файл **costs_info_short.csv**:
# - dt — дата проведения рекламной кампании,
# - Channel — идентификатор рекламного источника,
# - costs — расходы на эту кампанию.
# -----

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Проект:-Оценка-эффективности-проведения-рекламной-компании-приложения-Procrastinate-Pro+." data-toc-modified-id="Проект:-Оценка-эффективности-проведения-рекламной-компании-приложения-Procrastinate-Pro+.-1">Проект: Оценка эффективности проведения рекламной компании приложения Procrastinate Pro+.</a></span><ul class="toc-item"><li><span><a href="#1.-Цели-проекта:" data-toc-modified-id="1.-Цели-проекта:-1.1">1. Цели проекта:</a></span></li><li><span><a href="#2.-Задачи-проекта:" data-toc-modified-id="2.-Задачи-проекта:-1.2">2. Задачи проекта:</a></span></li><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-1.3">Описание данных:</a></span></li><li><span><a href="#3.-Предобработка-данных:" data-toc-modified-id="3.-Предобработка-данных:-1.4">3. Предобработка данных:</a></span><ul class="toc-item"><li><span><a href="#3.1-Импортируем-все-необходимые-библиотеки-для-работы-и-прочитаем-датасеты." data-toc-modified-id="3.1-Импортируем-все-необходимые-библиотеки-для-работы-и-прочитаем-датасеты.-1.4.1">3.1 Импортируем все необходимые библиотеки для работы и прочитаем датасеты.</a></span></li><li><span><a href="#3.2-Предобработка-датасета-сессий-пользователей." data-toc-modified-id="3.2-Предобработка-датасета-сессий-пользователей.-1.4.2">3.2 Предобработка датасета сессий пользователей.</a></span></li><li><span><a href="#3.3-Предобработка-датасета-заказов-пользователей." data-toc-modified-id="3.3-Предобработка-датасета-заказов-пользователей.-1.4.3">3.3 Предобработка датасета заказов пользователей.</a></span></li><li><span><a href="#3.4-Предобработка-датасета-с-рекламными-расходами." data-toc-modified-id="3.4-Предобработка-датасета-с-рекламными-расходами.-1.4.4">3.4 Предобработка датасета с рекламными расходами.</a></span></li></ul></li><li><span><a href="#4.-Расчёт-LTV,-ROI,-Retention-Rate-и-CR." data-toc-modified-id="4.-Расчёт-LTV,-ROI,-Retention-Rate-и-CR.-1.5">4. Расчёт LTV, ROI, Retention Rate и CR.</a></span><ul class="toc-item"><li><span><a href="#4.1-Функция-создания-профилей-пользователей." data-toc-modified-id="4.1-Функция-создания-профилей-пользователей.-1.5.1">4.1 Функция создания профилей пользователей.</a></span></li><li><span><a href="#4.2-Функция-для-подсчёта-Retention-Rate." data-toc-modified-id="4.2-Функция-для-подсчёта-Retention-Rate.-1.5.2">4.2 Функция для подсчёта Retention Rate.</a></span></li><li><span><a href="#4.3-Функция-для-подсчёта-конверсии(CR)." data-toc-modified-id="4.3-Функция-для-подсчёта-конверсии(CR).-1.5.3">4.3 Функция для подсчёта конверсии(CR).</a></span></li><li><span><a href="#4.4-Финальная-функция-для-подсчёта-LTV-и-ROI." data-toc-modified-id="4.4-Финальная-функция-для-подсчёта-LTV-и-ROI.-1.5.4">4.4 Финальная функция для подсчёта LTV и ROI.</a></span></li></ul></li><li><span><a href="#5.-Визуализация-LTV,-ROI,-Retention-Rate-и-CR." data-toc-modified-id="5.-Визуализация-LTV,-ROI,-Retention-Rate-и-CR.-1.6">5. Визуализация LTV, ROI, Retention Rate и CR.</a></span></li><li><span><a href="#6.-Исследовательский-анализ-данных." data-toc-modified-id="6.-Исследовательский-анализ-данных.-1.7">6. Исследовательский анализ данных.</a></span></li><li><span><a href="#7.-Анализ-маркетинговой-стратегии." data-toc-modified-id="7.-Анализ-маркетинговой-стратегии.-1.8">7. Анализ маркетинговой стратегии.</a></span><ul class="toc-item"><li><span><a href="#7.1-Оценка-маркетинговой-стратегии-компании." data-toc-modified-id="7.1-Оценка-маркетинговой-стратегии-компании.-1.8.1">7.1 Оценка маркетинговой стратегии компании.</a></span></li></ul></li></ul></li><li><span><a href="#Итог-проекта:" data-toc-modified-id="Итог-проекта:-2">Итог проекта:</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Итоги-исследования:" data-toc-modified-id="Итоги-исследования:-2.0.1">Итоги исследования:</a></span></li></ul></li><li><span><a href="#Рекомендации:" data-toc-modified-id="Рекомендации:-2.1">Рекомендации:</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## 3. Предобработка данных:

# %% [markdown]
# ### 3.1 Импортируем все необходимые библиотеки для работы и прочитаем датасеты.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import os

pd.set_option('float_format', '{:f}'.format)

# %%
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (20, 15)

# %%
visY = '/datasets/visits_info_short.csv'
visF = r'C:\Users\falku\visits_info_short.csv'
orderY = '/datasets/orders_info_short.csv'
orderF = r'C:\Users\falku\orders_info_short.csv'
costY = '/datasets/costs_info_short.csv'
costF = r'C:\Users\falku\costs_info_short.csv'

if os.path.exists(visF) and os.path.exists(orderF) and os.path.exists(costF):
    df_visit = pd.read_csv(visF)
    df_orders = pd.read_csv(orderF)
    df_cost = pd.read_csv(costF)
elif os.path.exists(visY) and os.path.exists(orderY) and os.path.exists(costY):
    df_visit = pd.read_csv(visY)
    df_orders = pd.read_csv(orderY)
    df_cost = pd.read_csv(costY)
else:
    print('Упс... что-то пошло не так')

# %% [markdown]
# ### 3.2 Предобработка датасета сессий пользователей.

# %%
df_visit.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
df_visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Все названия столбцов в датафрейме стоит привести к общему виду. Помимо этого, столбики `Session Start` и `Session End` имеют явно неверный тип данных.

# %%
df_visit.columns = ['user_id', 'region', 'device', 'channel', 'start_dt', 'end_dt']

# %%
df_visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   309901 non-null  int64
#  1   region    309901 non-null  object
#  2   device    309901 non-null  object
#  3   channel   309901 non-null  object
#  4   start_dt  309901 non-null  object
#  5   end_dt    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Помимо двух последних столбцов, было бы отлично определиться с типом данных у столбцов `region`, `device`, `channel`. Вполне возможно, количество уникальных записей в них сильно ограничено. Переведя данные в `category`, мы сможем сэкономить немного места и дадим сигнал другим библиотекам, которые в будущем будут с ними работать.

# %%
unique_counts = pd.DataFrame.from_records([(col, df_visit[col].nunique()) for col in df_visit.columns],
                                          columns=['column_name', 'num_unique']).sort_values(by=['num_unique'])

# %%
unique_counts
# Out:
#   column_name  num_unique
# 1      region           4
# 2      device           4
# 3     channel          11
# 0     user_id      150008
# 5      end_dt      306793
# 4    start_dt      306813

# %% [markdown]
# Теперь проверим датасет на явные дубликаты по всем столбцам и на наличие пропусков.

# %%
df_visit[df_visit[['user_id', 'region', 'device', 'channel', 'start_dt', 'end_dt']].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [user_id, region, device, channel, start_dt, end_dt]
# Index: []

# %%
df_visit.isna().sum()
# Out:
# user_id     0
# region      0
# device      0
# channel     0
# start_dt    0
# end_dt      0
# dtype: int64

# %% [markdown]
# ### 3.3 Предобработка датасета заказов пользователей.

# %%
df_orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52 4.990000
# 1  174361394180  2019-05-01 12:24:04 4.990000
# 2  529610067795  2019-05-01 11:34:04 4.990000
# 3  319939546352  2019-05-01 15:34:40 4.990000
# 4  366000285810  2019-05-01 13:59:51 4.990000

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# Тут идентичная ситуация, как и с данными о сессиях пользователей. Переменуем столбцы и переведём данные из `Event Dt` в  datetime.

# %%
df_orders.columns = ['user_id', 'event_dt', 'revenue']

# %% [markdown]
# Проверим датасет на явные дубликаты по всем столбцам и на наличие пропусков.

# %%
df_orders[df_orders[['user_id', 'event_dt', 'revenue']].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [user_id, event_dt, revenue]
# Index: []

# %%
df_orders.isna().sum()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %% [markdown]
# ### 3.4 Предобработка датасета с рекламными расходами.

# %%
df_cost.head()
# Out:
#            dt   Channel      costs
# 0  2019-05-01  FaceBoom 113.300000
# 1  2019-05-02  FaceBoom  78.100000
# 2  2019-05-03  FaceBoom  85.800000
# 3  2019-05-04  FaceBoom 136.400000
# 4  2019-05-05  FaceBoom 122.100000

# %%
df_cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
unique_counts = pd.DataFrame.from_records([(col, df_cost[col].nunique()) for col in df_cost.columns],
                                          columns=['column_name', 'num_unique']).sort_values(by=['num_unique'])

# %%
unique_counts
# Out:
#   column_name  num_unique
# 1     Channel          10
# 0          dt         180
# 2       costs         608

# %% [markdown]
# Переменуем столбец `Channel` и присвоим ему тип данных `category`.

# %%
df_cost.rename(columns = {'Channel':'channel'}, inplace = True)

# %%
df_cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Проверим датасет на явные дубликаты по всем столбцам и на наличие пропусков.

# %%
df_cost[df_cost[['dt', 'channel', 'costs']].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [dt, channel, costs]
# Index: []

# %%
df_cost.isna().sum()
# Out:
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# Приведём все столбцы к необходимым типам данных.

# %%
df_visit['start_dt'] = pd.to_datetime(df_visit['start_dt'])
df_visit['end_dt'] = pd.to_datetime(df_visit['end_dt'])
df_orders['event_dt'] = pd.to_datetime(df_orders['event_dt'])
df_visit['channel'] = df_visit['channel'].astype('category')
df_visit['region'] = df_visit['region'].astype('category')
df_visit['device'] = df_visit['device'].astype('category')
df_cost['channel'] = df_cost['channel'].astype('category')

# %% [markdown]
# **Таким образом, все названия столбцов были преобразованы к стилю `snake_case`, а столбцы с временными значениями и категориальными переменными к типам данных `datetime` и `category`, соответственно. Отлично, теперь все три датафрейма готовы к дальнейшей работе.**

# %% [markdown]
# ## 4. Расчёт LTV, ROI, Retention Rate и CR.

# %% [markdown]
# ### 4.1 Функция создания профилей пользователей.

# %%
def get_profiles(df_visit, df_orders, df_cost):

    profiles = (
        df_visit.sort_values(by=['user_id', 'start_dt'])
        .groupby('user_id')
        .agg(
            {
                'start_dt': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'start_dt': 'first_ts'})
        .reset_index()
    )
    
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    profiles['payer'] = profiles['user_id'].isin(df_orders['user_id'].unique())

    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    
    df_cost = df_cost.merge(new_users, on=['dt', 'channel'], how='left')
    df_cost['acquisition_cost'] = df_cost['costs'] / df_cost['unique_users']

    profiles = profiles.merge(
        df_cost[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left'
    )
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
df_cost['dt'] = pd.to_datetime(df_cost['dt']).dt.date

# %%
visits, orders, costs = (
    df_visit,  # журнал сессий
    df_orders,  # покупки
    df_cost,  # траты на рекламу
)

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Профили пользователей cформированы. Небольшой фактчекинг по сумме расходов не будет лишним.

# %%
profiles.acquisition_cost.sum()
# Out:
# 105497.29999999999

# %%
df_cost.costs.sum()
# Out:
# 105497.30000000002

# %% [markdown]
# ### 4.2 Функция для подсчёта Retention Rate.

# %%
def get_retention(
    profiles,
    df_visit,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    dimensions = ['payer'] + dimensions
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    result_raw = result_raw.merge(
        df_visit[['user_id', 'start_dt']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['start_dt'] - result_raw['first_ts']
    ).dt.days

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result


    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)


    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )


    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### 4.3 Функция для подсчёта конверсии(CR).

# %%
def get_conversion(
    profiles,
    df_orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    first_purchases = (
        df_orders.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    if 'cohort' in dimensions: 
        dimensions = []

    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### 4.4 Финальная функция для подсчёта LTV и ROI.

# %%
def get_ltv(
    profiles,
    df_orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        df_orders[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes

        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        roi = result.div(cac['cac'], axis=0)

        roi = roi[~roi['cohort_size'].isin([np.inf])]

        roi['cohort_size'] = cohort_sizes

        roi['cac'] = cac['cac']

        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    if 'cohort' in dimensions:
        dimensions = []

    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ## 5. Визуализация LTV, ROI, Retention Rate и CR.

# %% [markdown]
# Для более наглядного восприятия полученных данных, напишем ещё несколько функций их визуализации.

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    plt.figure(figsize=(15, 10))

    retention = retention.drop(columns=['cohort_size', 0])
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]


    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])


    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')


    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    ax3 = plt.subplot(2, 2, 3)
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    plt.figure(figsize=(15, 5))

    conversion = conversion.drop(columns=['cohort_size'])
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    plt.figure(figsize=(20, 10))

    ltv = ltv.drop(columns=['cohort_size'])
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    cac_history = roi_history[['cac']]

    roi = roi.drop(columns=['cohort_size', 'cac'])
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Все функции готовы, можно приступать к анализу данных.**

# %% [markdown]
# ## 6. Исследовательский анализ данных.

# %% [markdown]
# Определим минимальную и максимальную дату привлечения пользователей.

# %%
profiles.groupby('channel').agg(
    {'dt': ['min', 'max']})
# Out:
#                             dt
#                            min         max
# channel
# AdNonSense          2019-05-01  2019-10-27
# FaceBoom            2019-05-01  2019-10-27
# LeapBob             2019-05-01  2019-10-27
# MediaTornado        2019-05-01  2019-10-27
# OppleCreativeMedia  2019-05-01  2019-10-27
# RocketSuperAds      2019-05-01  2019-10-27
# TipTop              2019-05-01  2019-10-27
# WahooNetBanner      2019-05-01  2019-10-27
# YRabbit             2019-05-01  2019-10-27
# lambdaMediaAds      2019-05-01  2019-10-27
# organic             2019-05-01  2019-10-27

# %% [markdown]
# **Все рекламные компании проводились одинаковое количество дней, c 1-го мая 2019 года по 27-е октября того же года.**

# %% [markdown]
# Выясним, из каких стран чаще всего приходили пользователи и долю платящих среди них.

# %% [markdown]
# Для этого, напишем небольшую функцию:

# %%
def group_by_value(value):
    return profiles.groupby(value).agg({'user_id': ['count'], 'payer':'mean'}).sort_values(by = ('payer', 'mean'), ascending = False).style.format({('payer', 'mean'): "{:.2%}"})

# %%
group_by_value('region')
# Out:
# <style  type="text/css" >
# </style><table id="T_591d7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >count</th>        <th class="col_heading level1 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_591d7_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_591d7_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_591d7_row0_col1" class="data row0 col1" >6.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_591d7_level0_row1" class="row_heading level0 row1" >Germany</th>
# ...

# %% [markdown]
# **География пришедших пользователей насчитывает 4 страны. Если пользователей из Франции, Германии и Англии пришло примерно одинакое количество, то посетители из США составляют целых `66%` или `2/3` от общего числа.  Аналогичная ситуация и с долей платящих пользователей. Жители США становятся платящими клиентами почти в два раза чаще, чем пользователи из других стран.**

# %% [markdown]
# Выясним, какими устройствами чаще всего пользуются пользователи и долю платящих среди них.

# %%
group_by_value('device')
# Out:
# <style  type="text/css" >
# </style><table id="T_0377a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >count</th>        <th class="col_heading level1 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0377a_level0_row0" class="row_heading level0 row0" >Mac</th>
#                         <td id="T_0377a_row0_col0" class="data row0 col0" >30042</td>
#                         <td id="T_0377a_row0_col1" class="data row0 col1" >6.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_0377a_level0_row1" class="row_heading level0 row1" >iPhone</th>
# ...

# %% [markdown]
# **Пользователей iPhone почти в `1,5` раза больше, чем пользователей Android, но заметной разницы в долях платящих пользователей у мобильных операционных систем не наблюдается. Немного другая ситуация с десктопными операционными системами, доля пользователей PC и Mac идентична, однако пользователи PC становятся покупателями на `16-20%` реже, чем пользователи Mac OS и  пользователи мобильных OS.**

# %% [markdown]
# Теперь разберёмся с каналами привлечения, сколько пришло из каждого и какая доля приведённых стала покупателями.

# %%
group_by_value('channel')
# Out:
# <style  type="text/css" >
# </style><table id="T_b7be7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >count</th>        <th class="col_heading level1 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7be7_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#                         <td id="T_b7be7_row0_col0" class="data row0 col0" >29144</td>
#                         <td id="T_b7be7_row0_col1" class="data row0 col1" >12.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_b7be7_level0_row1" class="row_heading level0 row1" >AdNonSense</th>
# ...

# %% [markdown]
# **Два канала выделяются на фоне остальных по количеству привлечённых пользователей `FaceBoom` и `TipTop`. Порядка `52%` всех пользователей пришли в приложение через эти два канала. На оставшиеся 8 каналов приходится меньшая половина. Лучшими показателями по доле платящих пользователей обладают `FaceBoom` - 12,2%, `AdNonSense` - 11,3% и `lambdaMediaAds` - 10,4%.**

# %% [markdown]
# -----
# **Из полученных данных можем сделать следующие промежуточные выводы:**
# - Рекламная компания проводилась с 1-го мая 2019 года по 27-е октября 2019 года.
# - Пользователи приходят в приложение из Франции, Германии, Англии и США.
# - На США приходится наибольшая доля платящих пользователей.
# - Пользователи устанавливают приложение на 4 вида устройств: Android,iPhone,Mac,PC.
# - Наибольшая доля платящих пользователей у Mac.
# - Пользователи привлекались из 10-и платных каналов и "органическим" методом.
# - Наибольшая доля платящих пользователей у канала FaceBoom.
# -----

# %% [markdown]
# ## 7. Анализ маркетинговой стратегии.

# %% [markdown]
# Первым делом подсчитаем общую сумму маркетинговых расходов.

# %%
df_cost['costs'].sum()
# Out:
# 105497.30000000002

# %% [markdown]
# Теперь посмотрим, каким образом их распределили между 10-ю каналами привлечения.

# %%
df_cost.groupby('channel').agg({'costs': 'sum'}).sort_values(by = 'costs', ascending = False)
# Out:
#                           costs
# channel
# TipTop             54751.300000
# FaceBoom           32445.600000
# WahooNetBanner      5151.000000
# AdNonSense          3911.250000
# OppleCreativeMedia  2151.250000
# RocketSuperAds      1833.000000
# LeapBob             1797.600000
# lambdaMediaAds      1557.600000
# MediaTornado         954.480000
# YRabbit              944.220000

# %% [markdown]
# Построим визуализацию динамики изменения расходов во времени

# %%
df_cost['dt'] = pd.to_datetime(df_cost['dt'])

# %%
weekly_costs = df_cost.groupby(['channel', pd.Grouper(key='dt', freq='W-MON')])['costs'].sum().reset_index()
monthly_costs = df_cost.groupby(['channel', pd.Grouper(key='dt', freq='M')])['costs'].sum().reset_index()

# Создадим график
fig, axs = plt.subplots(2, 1, figsize=(15, 15))

# График по неделям
axs[0].set_title('Расходы в неделю')
for channel in weekly_costs['channel'].unique():
    channel_dt = weekly_costs[weekly_costs['channel'] == channel]
    axs[0].plot(channel_dt['dt'], channel_dt['costs'], label=channel)
    axs[0].legend()
    axs[0].set_xlabel('Неделя')
    axs[0].set_ylabel('Расходы (у.е.)')
    axs[0].grid(True)
    
# График по месяцам
axs[1].set_title('Расходы в месяц')
for channel in monthly_costs['channel'].unique():
    channel_dt = monthly_costs[monthly_costs['channel'] == channel]
    axs[1].plot(channel_dt['dt'], channel_dt['costs'], label=channel)
    axs[1].legend()
    axs[1].set_xlabel('Месяц')
    axs[1].set_ylabel('Расходы (у.е.)')
    axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# **По полученным данным и графикам видим, что `82%` всего рекламного бюджета ушло на оплату всего двух каналов: `FaceBoom` и `TipTop`.**

# %%
profiles['acquisition_cost'].mean()
# Out:
# 0.7032778251826568

# %% [markdown]
# Теперь узнаем, сколько в среднем стоило привлечение одного пользователя из каждого канала(CAC)

# %%
profiles.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean').sort_values('acquisition_cost', ascending = False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %% [markdown]
# **Пользователи из каналов `AdNonSense` и `FaceBoom` оказались довольно дорогостоящими по сравнению с остальными, больше 1 у.е. за пользователя. Однако даже они мекрнут на фоне стоимости привлечения пользователей из канала `TipTop`. Пользователи из `TipTop` стоили в 10 и более раз дороже пользователей из таких каналов как: `LeapBob`, `MediaTornado`, `OppleCreativeMedia` и `YRabbit`.**

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий</b></font>
#
# Учитывая, что на рекламу в платформе `TipTop` было выделено более половины всего рекламного бюджета, а он не вошёл даже в тройку лучших каналов по доле платящих пользователей, вполне вероятно, что он послужил причиной начавшихся убытков компании. Чтобы точно ответить на данный вопрос, необходимо углубиться в исследование качества пользователей.
#
# </div>

# %% [markdown]
# -----
# **Из полученных данных можем сделать следующие промежуточные выводы:**
# - Общий объём выделенных средств на рекламу - `105497 у.е.`
# - `82%` бюджета было потрачено на `20%` каналов. Явная диспропорция.
# - Средняя стоимость привлечения одного пользователя в эту рекламную компанию - `0,7 у.е.`
# - Более половины бюджета было выделено на рекламу в канале со стоимостью привлечения пользователя, превышающую средние показатели в `4 раза`.
# -----

# %% [markdown]
# ### 7.1 Оценка маркетинговой стратегии компании.

# %% [markdown]
# Установим момент и горизонт анализа данных.

# %%
profiles = profiles.query('channel != "organic"')
profiles.channel.value_counts()
# Out:
# FaceBoom              29144
# TipTop                19561
# OppleCreativeMedia     8605
# LeapBob                8553
# WahooNetBanner         8553
# RocketSuperAds         4448
# MediaTornado           4364
# YRabbit                4312
# AdNonSense             3880
# lambdaMediaAds         2149
# Name: channel, dtype: int64

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **По графикам можно сделать такие выводы:**
# - На LTV оказывает влияние сезонный фактор, но он всё же достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
# - CAC стабильно растёт с каждым месяцем.
# - Реклама убыточна, ROI на 14-й день так и не смог достигнуть точки окупаемости.
# - Динамика ROI 14-го дня демонстрирует нисходящее движение с самого старта рекламной компании.

# %% [markdown]
# **Обратимся к конверсии пользователей и её динамике.**

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=[]
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Будет полезно взглянуть на конверсию с разбивкой пользователей по устройствам, странам и каналам привлечения.

# %%
dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window = 14)

# %%
dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window = 14)

# %%
dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window = 14)

# %% [markdown]
# **Теперь перейдём к удержанию пользователей.**

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=[]
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
dimensions = ['device']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
dimensions = ['region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
dimensions = ['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# -----
# **По графикам можно сделать такие выводы:**
# - Конверсия пользователей на 14-й день достигает `~5,7%`.
# - Динамика конверсии пусть и подвержена колебаниям, но достаточно стабильна.
# - Худшей конверсией обладают пользователи PC, наилучшей - Mac.
# - Лучшей конверсией обладают пользователи из США.
# - Худший показатель удержания платящих пользователей также у США.
# - Каналы `FaceBoom` и `AdNonSense` обладают наилучшими показателями конверсии и наихудшими показателями удержания платящих пользователей.
# - Retention Rate платящих пользователей выше, чем у неплатящих, аномалий не наблюдается.
# - Динамика удержания достаточно стабильна.
# -----

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий</b></font>
#
# Беря во внимание, что общее качество пользователей находится в пределах нормы, как и конверсия с удержанием, необходимо более детально изучить, что же служит причиной стабильного падения ROI и постоянного роста расходов на привлечение пользователя (CAC).
#
# </div>

# %% [markdown]
# Для этого проанализируем окупаемость рекламы с разбивкой по устройствам, странам и каналам пользователей.

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Разделив пользователей по типу устройств, можно сделать вывод, что каких-то значимых отличий в их качестве нет. Однако на графике динамики стоимости привлечения заметны два лидера - это пользователи устройств компании Apple(Mac и iPhone), их привлечение обходится дороже всего и растёт быстрее стоимости PC и Android.

# %% [markdown]
# Учитывая, что LTV у всех пользователей одинаковое, довольно логичным выглядит ситуация, когда инвестиции в привлечение таких пользователей не окупаются и тянут всё ROI вниз. Что мы и наблюдаем на графике динамики ROI на 14-й день.

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# По графикам с делением пользователей по странам заметно, что LTV у пользователей из США на `15-16%` выше, чем у пользователей из других стран, однако, если мы взглянем на динамику стоимости привлечения пользователей, то увидим невероятный отрыв в негативную сторону. Пользователи из США обходятся в разы дороже пользователей из других стран.

# %% [markdown]
# Подобная ситуация не могла не сказаться на окупаемости инвестиций в рекламную компанию. Если пользователи из Франции,Германии и Англии "окупаются" уже на 3-4 день жизни, то пользователи из США не достигают необходимого уровня совсем.

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Несмотря на то, что на графике LTV пользователи из TipTop входят в тройку лидеров, данное качество нивелируется их стоимостью привлечения. Как уже отмечалось до этого, пользователи из TipTop стоят в разы дороже пользователей из других каналов.

# %% [markdown]
# Основываясь на показателях ROI для разных каналов, можно выделить инвестиции в рекламу на `YRabbit`, `MediaTornado`, `lambdaMediaAds` и `RocketSuperAds` как удачные, `OppleCreativeMedia` и `WahooNetBanner` как приемлемые, `AdNonSense`, `FaceBoom` и `TipTop` как неудачные.

# %% [markdown]
# **Учитывая схожесть в движении линий стоимости привлечения пользователей из США и пользователей через канал TipTop, было бы полезным понять, какой именно из этих двух факторов оказывает такое негативное влияние. Это общее свойство всех пользователей из США или это слишком дорогие расценки у TipTop ?**

# %%
df_tip = profiles.query('channel == "TipTop"')

# %%
df_tip['region'].value_counts()
# Out:
# United States    19561
# Name: region, dtype: int64

# %% [markdown]
# Неудивительно, что TipTop оказался специализированным каналом на пользователях из США.

# %%
df_usa = profiles.query('region == "United States"')

# %%
df_usa['channel'].value_counts()
# Out:
# FaceBoom          29144
# TipTop            19561
# RocketSuperAds     4448
# MediaTornado       4364
# YRabbit            4312
# Name: channel, dtype: int64

# %% [markdown]
# Из полученных данных следует, что проблема именно в каналах `TipTop` и `FaceBoom`, так как американские пользователи с `YRabbit`, `MediaTornado` и `RocketSuperAds` стоят в десятки раз дешевле и данные каналы обладают отличными показателями ROI.

# %% [markdown]
#  # Итог проекта:

# %% [markdown]
# ### Итоги исследования:

# %% [markdown]
# - `2/3` всех привлечённых пользователей - это пользователи из США.
# - Пользователей iPhone больше всего, но они становятся покупателями реже на `16-20%`.
# - `52%` всех пользователей пришли из каналов `FaceBoom` и `TipTop`.
# - `82%` всего рекламного бюджета было потрачено на `FaceBoom` и `TipTop`.
# - Пользователи из `TipTop` обошлись на `300%` дороже, чем в среднем по всем каналам.
# - Пользователи устройств `iPhone` и `Mac` обходятся слишком дорого и не успевают окупиться за 14 дней.
# - LTV пользователей из США выше на `15-16%`, чем у пользователей из Франции,Германии и Англии.
# - CAC пользователей из США в `4 раза больше`, чем у пользователей из Франции, Германии и Англии.
# - Пользователи из США `не окупаются` за 14-и дневный срок.
# - Точку безубыточности ROI прошли только пользователи, пришедшие из `YRabbit`, `MediaTornado`, `lambdaMediaAds`, `RocketSuperAds`, `OppleCreativeMedia`, `WahooNetBanner`.
# - Пользователи из `AdNonSense`, `FaceBoom` и `TipTop` привлекались в убыток компании.

# %% [markdown]
# ## Рекомендации:

# %% [markdown]
# - LTV недостаточен для окупаемости рекламных компаний. Необходимо либо сократить CAC на `20%`, либо увеличить LTV на аналогичные `20%` при сохранении текущих расходов.
# - Сосредоточиться на привлечении пользователей PC в приложение, как наиболее рентабельной аудитории (ROI).
# - Диверсифицировать распределение маркетингового бюджета, не допускать подобной концетрации средств в 1-2 каналах.
# - Отказаться от услуг рекламы в каналах `TipTop`, `FaceBoom` и `AdNonSense`.
# - Привлекать американских пользователей через каналы `YRabbit`, `MediaTornado` и `RocketSuperAds`.
# - Пользователей не из США лучше привлекать через каналы `lambdaMediaAds`, `OppleCreativeMedia` или `WahooNetBanner`.
